# %%
import pandas as pd



df2 = pd.read_csv('face.csv')

df = pd.read_csv('datarespon.csv')
df3 = pd.read_csv('faceNhair.csv')
df4 = pd.read_csv('another.csv')


problemsArray = [
    "รอยดำหรือรอยแดงจากสิว",
    "รูขุมขนกว้าง",
    "มีริ้วรอย",
    "ฝ้า กระ จุดด่างดำจากแดด",
    "หลุม แผลเป็นจากสิว",
    "ผิวหน้าหมองคล้ำ",
    "สิวอุดตัน ผดสิว",
    "ผิวแห้ง แพ้ง่าย"
]

df2
# Out:
#    คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด  \
# 0   ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# 1   ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# 2        ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย
# 3                                          ผิวหน้ามัน
# 4   ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# ..                                                ...
# 80       ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย
# 81                                        ผิวหน้าแห้ง
# 82  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# 83                                        ผิวหน้าแห้ง
# 84                                         ผิวหน้ามัน
#
#    ปัญหาผิวหน้าที่คุณประสบอยู่คืออะไร? (เลือกได้หลายข้อ)  \
# 0   รอยดำหรือรอยแดงจากสิว, ฝ้า กระ จุดด่างดำจากแดด...
# 1   รอยดำหรือรอยแดงจากสิว, รูขุมขนกว้าง, หลุม แผลเ...
# 2                 รอยดำหรือรอยแดงจากสิว, รูขุมขนกว้าง
# 3   รอยดำหรือรอยแดงจากสิว, รูขุมขนกว้าง, หลุม แผลเ...
# ...

# %% [markdown]
# สภาพผิวแบบไหนมีปัญหาแบบไหน

# %%
df2.groupby(["Problem1"])["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด"].value_counts()
# Out:
# Problem1                 คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด
# ผิวหน้าหมองคล้ำ          ผิวหน้าธรรมดา - มีความสมดุลไม่ค่อยมีสิว                       1
#                          ผิวหน้ามัน                                                    1
# ผิวแห้ง แพ้ง่าย          ผิวหน้าแห้ง                                                   1
# ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)     5
#                          ผิวหน้าแห้ง                                                   2
#                          ผิวหน้ามัน                                                    1
# มีริ้วรอย                ผิวหน้าแห้ง                                                   2
#                          ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย                  1
#                          ผิวหน้ามัน                                                    1
#                          ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)     1
# ...

# %%
df2.groupby(["Problem2"])["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด"].value_counts()
# Out:
# Problem2                  คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด
#  ผิวหน้าหมองคล้ำ          ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)     4
#                           ผิวหน้าธรรมดา - มีความสมดุลไม่ค่อยมีสิว                       1
#                           ผิวหน้าแห้ง                                                   1
#                           ผิวหน้ามัน                                                    1
#  ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)     4
#                           ผิวหน้าแห้ง                                                   2
#                           ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย                  1
#                           ผิวหน้ามัน                                                    1
#  มีริ้วรอย                ผิวหน้ามัน                                                    3
# ...

# %%
df2.groupby(["Problem2.1"])["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด"].value_counts()
# Out:
# Problem2.1                คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด
#  ผิวหน้าหมองคล้ำ          ผิวหน้ามัน                                                   4
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    3
#                           ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย                 2
#                           ผิวหน้าแห้ง                                                  1
#  ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    3
#                           ผิวหน้าแห้ง                                                  2
#                           ผิวหน้าธรรมดา - มีความสมดุลไม่ค่อยมีสิว                      1
#                           ผิวหน้ามัน                                                   1
#  มีริ้วรอย                ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    3
#                           ผิวหน้ามัน                                                   3
# ...

# %%
df2.groupby(["Problem3"])["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด"].value_counts()
# Out:
# Problem3                  คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด
#  ผิวหน้าหมองคล้ำ          ผิวหน้ามัน                                                   5
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    2
#                           ผิวหน้าแห้ง                                                  2
#  ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้ามัน                                                   2
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    1
#  หลุม แผลเป็นจากสิว       ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    2
#                           ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย                 2
#                           ผิวหน้าธรรมดา - มีความสมดุลไม่ค่อยมีสิว                      1
#                           ผิวหน้ามัน                                                   1
# Name: count, dtype: int64

# %%
df2.groupby(["Problem4"])["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด"].value_counts()
# Out:
# Problem4             คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด
#  ผิวหน้าหมองคล้ำ     ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    1
#                      ผิวหน้ามัน                                                   1
#                      ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย                 1
#  หลุม แผลเป็นจากสิว  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    1
#                      ผิวหน้ามัน                                                   1
# Name: count, dtype: int64

# %%
df2.groupby(["Problem5"])["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด"].value_counts()
# Out:
# Problem5          คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด
#  ผิวหน้าหมองคล้ำ  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)    1
#                   ผิวหน้ามัน                                                   1
# Name: count, dtype: int64

# %% [markdown]
# # สภาพผิว + รูขน = ปัญหา

# %%
df3
# Out:
#    คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด  \
# 0   ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# 1   ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# 2        ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย
# 3                                          ผิวหน้ามัน
# 4   ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# ..                                                ...
# 80       ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย
# 81                                        ผิวหน้าแห้ง
# 82  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จม...
# 83                                        ผิวหน้าแห้ง
# 84                                         ผิวหน้ามัน
#
#            รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร  \
# 0           ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )
# 1   รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )
# 2   รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )
# 3   รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )
# 4           ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )
# ...

# %%
df3.groupby(["Problem1"])[["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด", "รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร"]].value_counts()
# Out:
# Problem1                 คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด   รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร
# ผิวหน้าหมองคล้ำ          ผิวหน้าธรรมดา - มีความสมดุลไม่ค่อยมีสิว                    ไม่เคยสังเกต                                  1
#                          ผิวหน้ามัน                                                 ไม่เคยสังเกต                                  1
# ผิวแห้ง แพ้ง่าย          ผิวหน้าแห้ง                                                ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )             1
# ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )             3
#                          ผิวหน้าแห้ง                                                ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )             2
#                          ผิวหน้ามัน                                                 ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )             1
# ...

# %%
df3.groupby(["Problem2"])[["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด", "รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร"]].value_counts()
# Out:
# Problem2                  คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด   รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร
#  ผิวหน้าหมองคล้ำ          ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  ไม่เคยสังเกต                                 3
#                           ผิวหน้าธรรมดา - มีความสมดุลไม่ค่อยมีสิว                    ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            1
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                           ผิวหน้าแห้ง                                                ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            1
#                           ผิวหน้ามัน                                                 ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            1
#  ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            4
# ...

# %%
df3.groupby(["Problem3"])[["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด", "รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร"]].value_counts()
# Out:
# Problem3                  คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด   รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร
#  ผิวหน้าหมองคล้ำ          ผิวหน้ามัน                                                 รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    3
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            2
#                           ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย               รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    2
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                           ผิวหน้าแห้ง                                                ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            1
#                           ผิวหน้ามัน                                                 ไม่เคยสังเกต                                 1
# ...

# %%
df3.groupby(["Problem4"])[["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด", "รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร"]].value_counts()
# Out:
# Problem4                  คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด   รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร
#  ผิวหน้าหมองคล้ำ          ผิวหน้ามัน                                                 รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    4
#                           ผิวหน้าแห้ง                                                ค่อนข้างเล็ก ( สังเกตเห็นได้ยาก )            2
#                           ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                                                                                      ไม่เคยสังเกต                                 1
#                           ผิวหน้ามัน                                                 ไม่เคยสังเกต                                 1
#  ฝ้า กระ จุดด่างดำจากแดด  ผิวหน้ามัน                                                 รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    2
# ...

# %%
df3.groupby(["Problem5"])[["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด", "รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร"]].value_counts()
# Out:
# Problem5             คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด   รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร
#  ผิวหน้าหมองคล้ำ     ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                      ผิวหน้ามัน                                                 รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                      ผิวหน้าแพ้ง่าย - บอบบาง มีสิว ผดผื่นขึ้นง่าย               ไม่เคยสังเกต                                 1
#  หลุม แผลเป็นจากสิว  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                      ผิวหน้ามัน                                                 รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
# Name: count, dtype: int64

# %%
df3.groupby(["Problem6"])[["คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด", "รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร"]].value_counts()
# Out:
# Problem6          คุณรู้สึกว่าผิวหน้าของคุณใกล้เคียงกับตัวเลือกใดมากที่สุด   รูขุมขนบริเวณแก้มของคุณเป็นอย่างไร
#  ผิวหน้าหมองคล้ำ  ผิวหน้าผสม - มันเฉพาะบริเวณ T-Zone (หน้าผาก จมูก และ คาง)  รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
#                   ผิวหน้ามัน                                                 รูขุมขนกว้าง ( สังเกตเห็นได้อย่างชัดเจน )    1
# Name: count, dtype: int64

# %%
df4
# Out:
#                         area    area1    area2 area3  area4 area5    Level  \
# 0   หน้าผาก, แก้ม, คาง, จมูก  หน้าผาก     แก้ม   คาง   จมูก   NaN  ปานกลาง
# 1              หน้าผาก, แก้ม  หน้าผาก     แก้ม   NaN    NaN   NaN  ปานกลาง
# 2                       แก้ม     แก้ม      NaN   NaN    NaN   NaN  น้อยมาก
# 3              หน้าผาก, แก้ม  หน้าผาก     แก้ม   NaN    NaN   NaN  ปานกลาง
# 4                    หน้าผาก  หน้าผาก      NaN   NaN    NaN   NaN  น้อยมาก
# ..                       ...      ...      ...   ...    ...   ...      ...
# 73                       คาง      คาง      NaN   NaN    NaN   NaN  น้อยมาก
# 74                      จมูก     จมูก      NaN   NaN    NaN   NaN  น้อยมาก
# 75                      จมูก     จมูก      NaN   NaN    NaN   NaN  น้อยมาก
# 76              แก้ม, รอบปาก     แก้ม   รอบปาก   NaN    NaN   NaN  ปานกลาง
# 77             หน้าผาก, แก้ม  หน้าผาก     แก้ม   NaN    NaN   NaN  ปานกลาง
#
# ...

# %%
areaList = ["area1" , "area2", "area3","area4","area5"]
skinList = ["Skincare1","Skincare2","Skincare3","Skincare4","Skincare5","Skincare6","Skincare7"]

# %%
for area in areaList:
    for skin in skinList:
        counts = df4.groupby([area])[[skin, "Level" , "another"]].value_counts().reset_index(name='counts')
        # convert to csv
        counts.to_csv(area + skin + '.csv', index = False)
        print(counts)
# Out:
#       area1          Skincare1    Level another  counts
# 0       คาง       ครีมบำรุงผิว  ปานกลาง      มี       3
# 1       คาง       ครีมบำรุงผิว  น้อยมาก      มี       1
# 2       คาง             เซรั่ม  ปานกลาง   ไม่มี       1
# 3       คาง         ยารักษาสิว  น้อยมาก      มี       1
# 4       คาง       ครีมบำรุงผิว  ปานกลาง   ไม่มี       1
# 5      จมูก       ครีมบำรุงผิว  น้อยมาก   ไม่มี       3
# 6      จมูก       ครีมบำรุงผิว  น้อยมาก      มี       1
# 7    รอบปาก           โทนเนอร์  ปานกลาง   ไม่มี       1
# 8   หน้าผาก       ครีมบำรุงผิว  ปานกลาง   ไม่มี      12
# 9   หน้าผาก       ครีมบำรุงผิว  น้อยมาก      มี       5
# 10  หน้าผาก       ครีมบำรุงผิว  ปานกลาง      มี       5
# 11  หน้าผาก           โทนเนอร์  ปานกลาง      มี       2
# 12  หน้าผาก          มาส์กหน้า  ปานกลาง   ไม่มี       2
# 13  หน้าผาก        โฟมล้างหน้า  ปานกลาง   ไม่มี       2
# 14  หน้าผาก             เซรั่ม  ปานกลาง   ไม่มี       2
# 15  หน้าผาก             เซรั่ม  น้อยมาก   ไม่มี       2
# ...
